# %% [markdown]
# <a href="https://colab.research.google.com/github/olgakargan/-.ipynb-/blob/master/testABC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
upload=files.upload()
# Out:
#      <input type="file" id="files-4258a977-d6e1-4666-a2de-2d3da992026c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4258a977-d6e1-4666-a2de-2d3da992026c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', encoding='1251')

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-11  10:15:35     2173  2004598       2   22577
# 1  2022-08-11  10:27:46     2174  2004598       2   22577
# 2  2022-08-11  10:27:46     2174  2004598       2   22577
# 3  2022-08-11  10:27:46     2174  2004598       2   22577
# 4  2022-08-11  10:33:56     2175  2004598       2   22577
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18      45399
# 1  Розничная реализация       15     261519
# 2  Розничная реализация       15     460864
# 3  Розничная реализация       15     172823
# 4  Розничная реализация       18      79056
#
#                                            DR_NDrugs  ...  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...  ...
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.  ...
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...  ...
# 3  СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12...  ...
# ...

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller than the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# ...

# %%
from IPython.core import display_trap
pd.get_option('display.max_columns',40)
# Out:
# 20

# %%
df.tail()
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 4457  2022-08-12  21:40:17     5690  18002542      18    9907
# 4458  2022-08-12  21:40:59     5691  18002542      18    9907
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 4457  Розничная реализация       18     463100
# 4458  Розничная реализация       18     112158
# 4459  Розничная реализация       18     260990
# 4460  Розничная реализация       18      41512
# 4461  Розничная реализация       15      25673
#
#                                               DR_NDrugs  ...  \
# 4457  КЕТОРОЛ ЭКСПРЕСС 10МГ. №20 ТАБ. ДИСПЕРГ. /Д-Р ...  ...
# 4458                           АНТИПОЛИЦАЙ ВАЙТ №6 ТАБ.  ...
# 4459  СИЛДЕНАФИЛ-СЗ 50МГ. №10 ТАБ. П/П/О /СЕВЕРНАЯ З...  ...
# ...

# %%
pd.set_option('display.max_columns',40)

# %%
df.dtypes
# Out:
# DR_Dat         object
# DR_Tim         object
# DR_NChk         int64
# DR_NDoc         int64
# DR_Apt          int64
# DR_Kkm          int64
# DR_TDoc        object
# DR_TPay         int64
# DR_CDrugs       int64
# DR_NDrugs      object
# DR_Suppl       object
# DR_Prod        object
# DR_Kol        float64
# DR_CZak       float64
# DR_CRoz       float64
# DR_SDisc      float64
# DR_CDisc      float64
# DR_BCDisc     float64
# DR_TabEmpl      int64
# DR_VZak         int64
# DR_Pos        float64
# dtype: object

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.shape
# Out:
# (4462, 21)

# %%
df.columns
# Out:
# Index(['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc', 'DR_Apt', 'DR_Kkm', 'DR_TDoc',
#        'DR_TPay', 'DR_CDrugs', 'DR_NDrugs', 'DR_Suppl', 'DR_Prod', 'DR_Kol',
#        'DR_CZak', 'DR_CRoz', 'DR_SDisc', 'DR_CDisc', 'DR_BCDisc', 'DR_TabEmpl',
#        'DR_VZak', 'DR_Pos'],
#       dtype='object')

# %%
our_cols = ['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc','DR_Apt','DR_NDrugs','DR_Kol', 'DR_CZak', 'DR_CRoz', 'DR_SDisc',
       'DR_TPay', 'DR_CDrugs',  'DR_Suppl', 'DR_CDisc', 'DR_BCDisc', 'DR_TabEmpl','DR_VZak', 'DR_Pos']

# %%
df = df[our_cols]

# %%
df.columns = ['dt', 'c_tim', 'nChk', 'ndoc', 'apt','drug','kol', 'zak', 'roz', 'disc',
       'pay_tepe', 'drug_id',  'suppl', 'disc_id', 'disc_barcode', 'empl','vzak', 'pos']

# %%
df
# Out:
#               dt     c_tim  nChk      ndoc  apt  \
# 0     2022-08-11  10:15:35  2173   2004598    2
# 1     2022-08-11  10:27:46  2174   2004598    2
# 2     2022-08-11  10:27:46  2174   2004598    2
# 3     2022-08-11  10:27:46  2174   2004598    2
# 4     2022-08-11  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  2022-08-12  21:40:17  5690  18002542   18
# 4458  2022-08-12  21:40:59  5691  18002542   18
# 4459  2022-08-12  21:43:48  5692  18002542   18
# 4460  2022-08-12  21:44:46  5693  18002542   18
# 4461  2022-08-12  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %%
df['disc_barcode'] = df['disc_barcode'].astype('str').replace('\.0', '', regex=True)

# %%
df['disc_id'] = df['disc_id'].astype('str').replace('\.0', '', regex=True)

# %%
df.dtypes
# Out:
# dt               object
# c_tim            object
# nChk              int64
# ndoc              int64
# apt               int64
# drug             object
# kol             float64
# zak             float64
# roz             float64
# disc            float64
# pay_tepe          int64
# drug_id           int64
# suppl            object
# disc_id          object
# disc_barcode     object
# empl              int64
# vzak              int64
# pos             float64
# dtype: object

# %%
df['dt']= pd.to_datetime(df['dt']).dt.strftime('%d.%m.%y')

# %%
df['dt']
# Out:
# 0       11.08.22
# 1       11.08.22
# 2       11.08.22
# 3       11.08.22
# 4       11.08.22
#           ...
# 4457    12.08.22
# 4458    12.08.22
# 4459    12.08.22
# 4460    12.08.22
# 4461    12.08.22
# Name: dt, Length: 4462, dtype: object

# %%
df['vzak'].unique()
# Out:
# array([1, 2])

# %%
df['vzak'] = df['vzak'].astype('str').replace('1', 'Обычный').replace('2', 'Интернет')

# %%
df['vzak'].unique()
# Out:
# array(['Обычный', 'Интернет'], dtype=object)

# %%
df.isna().any()
# Out:
# dt              False
# c_tim           False
# nChk            False
# ndoc            False
# apt             False
# drug            False
# kol             False
# zak             False
# roz             False
# disc            False
# pay_tepe        False
# drug_id         False
# suppl           False
# disc_id          True
# disc_barcode    False
# empl            False
# vzak            False
# pos             False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4462 entries, 0 to 4461
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dt            4462 non-null   object
#  1   c_tim         4462 non-null   object
#  2   nChk          4462 non-null   int64
#  3   ndoc          4462 non-null   int64
#  4   apt           4462 non-null   int64
#  5   drug          4462 non-null   object
#  6   kol           4462 non-null   float64
#  7   zak           4462 non-null   float64
#  8   roz           4462 non-null   float64
#  9   disc          4462 non-null   float64
#  10  pay_tepe      4462 non-null   int64
#  11  drug_id       4462 non-null   int64
#  12  suppl         4462 non-null   object
#  13  disc_id       1765 non-null   float64
#  14  disc_barcode  4462 non-null   object
#  15  empl          4462 non-null   int64
#  16  vzak          4462 non-null   object
#  17  pos           4462 non-null   float64
# ...

# %%
df.describe()
# Out:
#          nChk        ndoc     apt     kol      zak      roz    disc  pay_tepe  \
# count 4462.00     4462.00 4462.00 4462.00  4462.00  4462.00 4462.00   4462.00
# mean  4903.14 10842995.33   10.84    1.03   241.64   306.05   10.56     16.90
# std   1839.70  6107181.40    6.11    0.54   454.56   532.17   31.37      1.45
# min   1698.00  2004595.00    2.00    0.01     0.01     0.01    0.00     15.00
# 25%   4187.00  6003620.00    6.00    1.00    36.64    52.00    0.00     15.00
# 50%   4877.50 11007039.00   11.00    1.00   103.78   137.00    0.00     18.00
# 75%   5472.75 18002536.00   18.00    1.00   299.06   391.75    7.00     18.00
# max   8490.00 18002543.00   18.00   20.00 11851.13 12345.00  650.00     18.00
#
#          drug_id  disc_id    empl     pos
# count    4462.00  1765.00 4462.00 4462.00
# mean   259227.09   156.56   91.74    2.68
# std    299073.90   327.36  108.08    2.75
# min         3.00     9.00   25.00    1.00
# 25%     29060.00     9.00   37.00    1.00
# ...

# %%
df['pay_tepe'].value_counts()
# Out:
# 18    2820
# 15    1642
# Name: pay_tepe, dtype: int64

# %%
df.apt.value_counts()
# Out:
# 18    1207
# 2      979
# 11     870
# 6      511
# 13     322
# 17     243
# 15     177
# 7      153
# Name: apt, dtype: int64

# %%
df.apt.value_counts(normalize=True)
# Out:
# 18   0.27
# 2    0.22
# 11   0.19
# 6    0.11
# 13   0.07
# 17   0.05
# 15   0.04
# 7    0.03
# Name: apt, dtype: float64

# %%
df.pos.hist(bins=24)
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
 plt.figure(figsize= (40, 20))

# %%
plt.figure(figsize= (20, 6))
sns.heatmap(df.corr(), vmax=1, vmin=-1,annot=True)
# Out:
# <ipython-input-34-154780b99f28>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), vmax=1, vmin=-1,annot=True)
# <Axes: >

# %%
df['hour'] = pd.to_datetime(df.c_tim).dt.hour

# %%
df['hour']
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 4457    21
# 4458    21
# 4459    21
# 4460    21
# 4461    21
# Name: hour, Length: 4462, dtype: int64

# %%
df.groupby(['hour'])['kol'].agg(sum)
# Out:
# hour
# 8     20.10
# 9    236.50
# 10   361.65
# 11   326.55
# 12   311.59
# 13   422.80
# 14   358.30
# 15   432.97
# 16   375.88
# 17   375.45
# 18   457.50
# 19   419.29
# 20   388.57
# 21    97.71
# 22     1.00
# Name: kol, dtype: float64

# %%
gr = df.groupby(['hour'])['kol'].agg(sum)

# %%
sns.boxplot()

# %%
a = df.groupby(['dt', 'nChk'])['kol', 'roz', 'zak'].agg({
    'kol': sum,
    'roz': ['sum', 'max'],
    'zak': sum})
# Out:
# <ipython-input-40-87f71ac85416>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a = df.groupby(['dt', 'nChk'])['kol', 'roz', 'zak'].agg({

# %%
a.index
# Out:
# MultiIndex([('11.08.22', 1698),
#             ('11.08.22', 1699),
#             ('11.08.22', 1700),
#             ('11.08.22', 1701),
#             ('11.08.22', 1702),
#             ('11.08.22', 1703),
#             ('11.08.22', 1704),
#             ('11.08.22', 1705),
#             ('11.08.22', 1706),
#             ('11.08.22', 1707),
#             ...
#             ('12.08.22', 8481),
#             ('12.08.22', 8482),
#             ('12.08.22', 8483),
#             ('12.08.22', 8484),
#             ('12.08.22', 8485),
#             ('12.08.22', 8486),
#             ('12.08.22', 8487),
#             ('12.08.22', 8488),
#             ('12.08.22', 8489),
#             ('12.08.22', 8490)],
#            names=['dt', 'nChk'], length=1941)

# %%
a.reset_index()
# Out:
#             dt  nChk   kol     roz           zak
#                        sum     sum    max    sum
# 0     11.08.22  1698  1.00  463.00 463.00 342.30
# 1     11.08.22  1699  1.00  720.00 720.00 545.27
# 2     11.08.22  1700  1.00   60.00  60.00  36.68
# 3     11.08.22  1701  4.00  955.00 443.00 756.12
# 4     11.08.22  1702  1.00   94.00  94.00  76.55
# ...        ...   ...   ...     ...    ...    ...
# 1936  12.08.22  8486  1.00  460.00 460.00 302.07
# 1937  12.08.22  8487  1.00  476.00 476.00 396.66
# 1938  12.08.22  8488  1.00  220.00 220.00 187.84
# 1939  12.08.22  8489 18.00 1089.00 180.00 778.61
# 1940  12.08.22  8490  3.00  869.00 775.00 626.13
#
# [1941 rows x 6 columns]

# %%
a= df.groupby(['dt', 'empl'])['zak', 'roz'].agg(sum)
# Out:
# <ipython-input-43-7ab9a846f983>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a= df.groupby(['dt', 'empl'])['zak', 'roz'].agg(sum)

# %%
a['revenue']= a['roz'] - a['zak']

# %%
df.groupby(['dt', 'empl'])['zak', 'roz'].apply(lambda x: sum(x['roz'] - x['zak']))
# Out:
# <ipython-input-45-8ebf1705de30>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['dt', 'empl'])['zak', 'roz'].apply(lambda x: sum(x['roz'] - x['zak']))
# dt        empl
# 11.08.22  25     21025.76
#           30     21566.56
#           36     14942.71
#           47     18167.68
#           50     18525.60
#           53     11018.92
#           54     14636.27
#           123    27751.82
#           205     9566.58
#           605     8254.36
# 12.08.22  37     25402.44
#           48     20258.42
#           54     17376.53
#           110    24148.58
#           123    24932.86
#           205     9822.84
# dtype: float64

# %%
a['revenue']= a['roz'] - a['zak']

# %%
a
# Out:
#                    zak       roz  revenue
# dt       empl
# 11.08.22 25   72004.24  93030.00 21025.76
#          30   90350.41 111916.97 21566.56
#          36   62425.32  77368.03 14942.71
#          47   68458.33  86626.01 18167.68
#          50   72304.41  90830.01 18525.60
#          53   37727.08  48746.00 11018.92
#          54   52880.81  67517.08 14636.27
#          123  88926.21 116678.03 27751.82
#          205  49904.42  59471.00  9566.58
#          605  28699.65  36954.01  8254.36
# 12.08.22 37   92688.93 118091.37 25402.44
#          48   72773.60  93032.02 20258.42
#          54   65852.52  83229.05 17376.53
#          110  89126.47 113275.05 24148.58
#          123  99298.80 124231.66 24932.86
#          205  34772.17  44595.01  9822.84

# %%
import numpy as np

# %%
df.groupby(['dt', 'drug'])['roz', 'kol'].agg({
    'roz':np.mean,
    'kol':sum
})
# Out:
# <ipython-input-49-3659e5f38a71>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['dt', 'drug'])['roz', 'kol'].agg({
#                                                                 roz  kol
# dt       drug
# 11.08.22 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА     111.00 1.00
#          911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.        104.00 1.00
#          L-ТИРОКСИН 150МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/          170.00 1.00
#          L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/             93.00 1.00
#          ZD ТЕЙМУРОВА СПРЕЙ Д/НОГ П/ПОТА И ЗАПАХА 150МЛ....   96.00 1.00
# ...                                                             ...  ...
# 12.08.22 ЭУФИЛЛИН 150МГ. №30 ТАБ. /ФАРМСТАНДАРТ/              31.00 2.00
#          ЮНИЭНЗИМ С МПС №20 ТАБ. П/О                         141.00 1.00
#          Я ЗАБОЧУСЬ О ЗДОРОВЬЕ ТРАВЯН.КОФЕ КОФЕЙНЫЙ НАПИ...  145.00 1.00
# ...

# %%
df['rroz'] = df.roz.apply(lambda x: round(x, -2))

# %%
a = df.groupby(['dt', 'rroz'])['kol'].agg(sum).reset_index()

# %%
a
# Out:
#           dt     rroz    kol
# 0   11.08.22     0.00 770.00
# 1   11.08.22   100.00 742.00
# 2   11.08.22   200.00 328.43
# 3   11.08.22   300.00 196.20
# 4   11.08.22   400.00 133.00
# ..       ...      ...    ...
# 68  12.08.22  4400.00   1.00
# 69  12.08.22  5000.00   1.00
# 70  12.08.22  5800.00   1.00
# 71  12.08.22 10200.00   1.00
# 72  12.08.22 12300.00   1.00
#
# [73 rows x 3 columns]

# %%
sns.scatterplot(a.rroz, a.kol, hue = a.dt)

# %%
sns.jointplot(a.rroz, a.kol)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4462 entries, 0 to 4461
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dt            4462 non-null   object
#  1   c_tim         4462 non-null   object
#  2   nChk          4462 non-null   int64
#  3   ndoc          4462 non-null   int64
#  4   apt           4462 non-null   int64
#  5   drug          4462 non-null   object
#  6   kol           4462 non-null   float64
#  7   zak           4462 non-null   float64
#  8   roz           4462 non-null   float64
#  9   disc          4462 non-null   float64
#  10  pay_tepe      4462 non-null   int64
#  11  drug_id       4462 non-null   int64
#  12  suppl         4462 non-null   object
#  13  disc_id       1765 non-null   float64
#  14  disc_barcode  4462 non-null   object
#  15  empl          4462 non-null   int64
#  16  vzak          4462 non-null   object
#  17  pos           4462 non-null   float64
# ...

# %%
b=df.groupby(['dt', 'apt', 'empl', 'pay_tepe'])['kol'].agg(sum).reset_index()

# %%
b
# Out:
#           dt  apt  empl  pay_tepe    kol
# 0   11.08.22    2   123        15 151.05
# 1   11.08.22    2   123        18 164.13
# 2   11.08.22    2   205        15  65.11
# 3   11.08.22    2   205        18  66.00
# 4   11.08.22    6    25        15  95.00
# 5   11.08.22    6    25        18 142.53
# 6   11.08.22    7   605        15  67.04
# 7   11.08.22    7   605        18 101.85
# 8   11.08.22   11    30        15 179.00
# 9   11.08.22   11    30        18 310.48
# 10  11.08.22   13    50        15 180.40
# 11  11.08.22   13    50        18 151.78
# 12  11.08.22   15    53        15  51.98
# 13  11.08.22   15    53        18 142.10
# 14  11.08.22   17    36        15  54.73
# 15  11.08.22   17    36        18 186.94
# 16  11.08.22   18    47        15  89.04
# 17  11.08.22   18    47        18 236.24
# 18  11.08.22   18    54        15  65.10
# 19  11.08.22   18    54        18 198.77
# 20  12.08.22    2   123        15 210.50
# 21  12.08.22    2   123        18 152.72
# ...

# %%
b.pivot_table(values='kol', index=['dt', 'apt', 'empl'], columns=['pay_tepe'])
# Out:
# pay_tepe              15     18
# dt       apt empl
# 11.08.22 2   123  151.05 164.13
#              205   65.11  66.00
#          6   25    95.00 142.53
#          7   605   67.04 101.85
#          11  30   179.00 310.48
#          13  50   180.40 151.78
#          15  53    51.98 142.10
#          17  36    54.73 186.94
#          18  47    89.04 236.24
#              54    65.10 198.77
# 12.08.22 2   123  210.50 152.72
#              205   88.41  80.19
#          6   37    72.92 207.89
#          11  110   91.67 363.08
#          18  48   134.79 222.65
#              54    64.10 197.65

# %%
c = df.pivot_table(values='roz', index=['dt', 'apt', 'empl'], columns=['pay_tepe'],aggfunc=sum)

# %%
c
# Out:
# pay_tepe                15       18
# dt       apt empl
# 11.08.22 2   123  55981.01 60697.02
#              205  27403.00 32068.00
#          6   25   27402.00 65628.00
#          7   605  17618.00 19336.01
#          11  30   38692.32 73224.65
#          13  50   44746.00 46084.01
#          15  53   20155.00 28591.00
#          17  36   20890.00 56478.03
#          18  47   25685.01 60941.00
#              54   12118.00 55399.08
# 12.08.22 2   123  48816.00 75415.66
#              205  16604.00 27991.01
#          6   37   37812.00 80279.37
#          11  110  14770.03 98505.02
#          18  48   37226.00 55806.02
#              54   14297.00 68932.05

# %%
c= c.reset_index()

# %%
pd.melt(c, id_vars=['dt', 'apt', 'empl'], value_vars=[15,18], var_name='p_type')
# Out:
#           dt  apt  empl p_type    value
# 0   11.08.22    2   123     15 55981.01
# 1   11.08.22    2   205     15 27403.00
# 2   11.08.22    6    25     15 27402.00
# 3   11.08.22    7   605     15 17618.00
# 4   11.08.22   11    30     15 38692.32
# 5   11.08.22   13    50     15 44746.00
# 6   11.08.22   15    53     15 20155.00
# 7   11.08.22   17    36     15 20890.00
# 8   11.08.22   18    47     15 25685.01
# 9   11.08.22   18    54     15 12118.00
# 10  12.08.22    2   123     15 48816.00
# 11  12.08.22    2   205     15 16604.00
# 12  12.08.22    6    37     15 37812.00
# 13  12.08.22   11   110     15 14770.03
# 14  12.08.22   18    48     15 37226.00
# 15  12.08.22   18    54     15 14297.00
# 16  11.08.22    2   123     18 60697.02
# 17  11.08.22    2   205     18 32068.00
# 18  11.08.22    6    25     18 65628.00
# 19  11.08.22    7   605     18 19336.01
# 20  11.08.22   11    30     18 73224.65
# 21  11.08.22   13    50     18 46084.01
# ...

# %%
df.iloc[2,5]
# Out:
# 'СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ 125МЛ.'

# %%
df.iloc[2:5, 3:5]
# Out:
#       ndoc  apt
# 2  2004598    2
# 3  2004598    2
# 4  2004598    2

# %%
df.loc[2:5,['zak','roz']]
# Out:
#      zak    roz
# 2 132.69 209.00
# 3 133.65 210.00
# 4 709.95 787.00
# 5 152.90 182.00

# %%
df.at[2,'zak']
# Out:
# 132.69

# %%
df.iat[2,5]
# Out:
# 'СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ 125МЛ.'

# %%
df[(df['kol']>5) | (df['roz']>2000)]
# Out:
#             dt     c_tim  nChk      ndoc  apt  \
# 27    11.08.22  11:50:16  2184   2004598    2
# 29    11.08.22  11:50:16  2184   2004598    2
# 45    11.08.22  13:10:54  2192   2004598    2
# 62    11.08.22  14:47:12  2201   2004598    2
# 65    11.08.22  14:52:33  2203   2004598    2
# ...        ...       ...   ...       ...  ...
# 3967  12.08.22  16:33:37  4368  18002543   18
# 3983  12.08.22  17:02:34  4375  18002543   18
# 4057  12.08.22  19:29:31  4422  18002543   18
# 4058  12.08.22  19:29:31  4422  18002543   18
# 4247  12.08.22  12:37:38  5561  18002542   18
#
#                                                    drug  kol      zak  \
# 27    АКАТИНОЛ МЕМАНТИН 20МГ. №28 ТАБ. П/П/О /МЕРЦ Ф... 1.00  2545.84
# 29                 ПРАДАКСА 110МГ. №60 КАПС. /БЕРИНГЕР/ 1.00  3076.03
# 45          ЦЕФАЛИ АППАРАТ Д/ТЕРАПИИ МИГРЕНИ С ПРИНАДЛ. 1.00 11851.13
# 62             ДЖАРДИНС 10МГ. №30 ТАБ. П/П/О /БЕРИНГЕР/ 1.00  2669.94
# ...

# %%
df[~df.loc[:,'pay_tepe'].isin([15,20])]
# Out:
#             dt     c_tim  nChk      ndoc  apt  \
# 0     11.08.22  10:15:35  2173   2004598    2
# 4     11.08.22  10:33:56  2175   2004598    2
# 5     11.08.22  10:40:38  2176   2004598    2
# 6     11.08.22  10:40:38  2176   2004598    2
# 7     11.08.22  10:52:52  2177   2004598    2
# ...        ...       ...   ...       ...  ...
# 4456  12.08.22  21:39:23  5689  18002542   18
# 4457  12.08.22  21:40:17  5690  18002542   18
# 4458  12.08.22  21:40:59  5691  18002542   18
# 4459  12.08.22  21:43:48  5692  18002542   18
# 4460  12.08.22  21:44:46  5693  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 4                      ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/ 1.00 709.95 787.00
# 5              БИСОПРОЛОЛ 5МГ. №60 ТАБ. П/П/О /ВЕРТЕКС/ 1.00 152.90 182.00
# 6                  ТРИХОПОЛ 250МГ. №20 ТАБ. /ПОЛЬФАРМА/ 1.00  67.94  85.00
# ...

# %%
d={
    'Обычный': 'Simpl',
    'Интернет': ' Web'
}
df['vzak'].map(d)
# Out:
# 0       Simpl
# 1       Simpl
# 2       Simpl
# 3       Simpl
# 4       Simpl
#         ...
# 4457    Simpl
# 4458    Simpl
# 4459    Simpl
# 4460    Simpl
# 4461    Simpl
# Name: vzak, Length: 4462, dtype: object

# %%
df['vzak']
# Out:
# 0       Обычный
# 1       Обычный
# 2       Обычный
# 3       Обычный
# 4       Обычный
#          ...
# 4457    Обычный
# 4458    Обычный
# 4459    Обычный
# 4460    Обычный
# 4461    Обычный
# Name: vzak, Length: 4462, dtype: object

# %%
df.head(2)
# Out:
#          dt     c_tim  nChk     ndoc  apt  \
# 0  11.08.22  10:15:35  2173  2004598    2
# 1  11.08.22  10:27:46  2174  2004598    2
#
#                                                 drug  kol   zak   roz  disc  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00 41.08 51.00 12.00
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00 18.61 31.00  3.00
#
#    pay_tepe  drug_id           suppl  disc_id  disc_barcode  empl     vzak  \
# 0        18    45399  Катрен г.Химки   925.00  200000000492   205  Обычный
# 1        15   261519  Катрен г.Химки     9.00  200010010204   205  Обычный
#
#    pos  hour   rroz
# 0 1.00    10 100.00
# 1 1.00    10   0.00

# %%
from pandas.core.groupby import groupby
groupped_df= df.groupby('drug').agg({'kol':sum})
groupped_df
# Out:
#                                                     kol
# drug
# 7 СЕМЬ ДНЕЙ МАСКА Д/ЛИЦА СУББОТА РОМАНТ. ПЕРЕД ... 1.00
# 9 МЕСЯЦЕВ ФОЛИЕВАЯ К-ТА 0,4МГ. №30 ТАБ. П/П/О /... 1.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА    2.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.       2.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/ТЕЛА БИШОФИТ П/БОЛИ В СУСТАВ... 1.00
# ...                                                 ...
# Я САМАЯ ВАТНЫЕ ПАЛОЧКИ №100 СТАКАН                 1.00
# ЯНТАРНАЯ К-ТА 100МГ. №10 ТАБ. (БАД) /МАРБИОФАРМ/   2.00
# ЯНТАРНАЯ К-ТА ПРЕМИУМ 100МГ. №20 ТАБ. (БАД) /БА... 1.00
# ЯНТАРНАЯ К-ТА ФОРП 100МГ. №10 ТАБ.                 3.00
# ЯРИНА №21 ТАБ. П/П/О                               1.00
#
# [1876 rows x 1 columns]

# %%
groupped_df=(groupped_df['kol']/sum(groupped_df['kol'])).sort_values(ascending=False)

# %%
groupped_df
# Out:
# drug
# ПАКЕТ                                                                         0.03
# ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /ЛЕККО/                          0.01
# НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/                              0.01
# ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/                                   0.01
# СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТАДА/                            0.01
#                                                                               ...
# НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ. /МОСФАРМ/                      0.00
# СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM]                             0.00
# ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР. Н/ОПУДР Р.L №50 (25ПАР)       0.00
# СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM]                              0.00
# СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/ОПУДР. Р.L №100 (50ПАР) [SFM]   0.00
# Name: kol, Length: 1876, dtype: float64

# %%
groupped_df=groupped_df.cumsum().reset_index()

# %%
groupped_df
# Out:
#                                                    drug  kol
# 0                                                 ПАКЕТ 0.03
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /... 0.04
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/ 0.05
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/ 0.06
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ... 0.07
# ...                                                 ...  ...
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 1.00
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 1.00
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 1.00
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 1.00
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 1.00
#
# [1876 rows x 2 columns]

# %%
groupped_df['abc'] = np.where(groupped_df['kol']<0.8,'A',np.where(groupped_df['kol']<0.95,'B','C'))

# %%
groupped_df
# Out:
#                                                    drug  kol abc
# 0                                                 ПАКЕТ 0.03   A
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /... 0.04   A
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/ 0.05   A
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/ 0.06   A
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ... 0.07   A
# ...                                                 ...  ...  ..
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 1.00   C
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 1.00   C
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 1.00   C
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 1.00   C
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 1.00   C
#
# [1876 rows x 3 columns]

# %%
groupped_df= df.groupby('drug').agg({'kol':sum, 'roz':sum})
groupped_df
# Out:
#                                                     kol     roz
# drug
# 7 СЕМЬ ДНЕЙ МАСКА Д/ЛИЦА СУББОТА РОМАНТ. ПЕРЕД ... 1.00   93.00
# 9 МЕСЯЦЕВ ФОЛИЕВАЯ К-ТА 0,4МГ. №30 ТАБ. П/П/О /... 1.00  144.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА    2.00  216.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.       2.00  208.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/ТЕЛА БИШОФИТ П/БОЛИ В СУСТАВ... 1.00  100.00
# ...                                                 ...     ...
# Я САМАЯ ВАТНЫЕ ПАЛОЧКИ №100 СТАКАН                 1.00   65.00
# ЯНТАРНАЯ К-ТА 100МГ. №10 ТАБ. (БАД) /МАРБИОФАРМ/   2.00   27.00
# ЯНТАРНАЯ К-ТА ПРЕМИУМ 100МГ. №20 ТАБ. (БАД) /БА... 1.00   52.00
# ЯНТАРНАЯ К-ТА ФОРП 100МГ. №10 ТАБ.                 3.00   28.00
# ЯРИНА №21 ТАБ. П/П/О                               1.00 1292.00
#
# [1876 rows x 2 columns]

# %%
groupped_df['rel_kol']=(groupped_df['kol']/sum(groupped_df['kol']))

# %%
groupped_df
# Out:
#                                                     kol     roz  rel_kol
# drug
# 7 СЕМЬ ДНЕЙ МАСКА Д/ЛИЦА СУББОТА РОМАНТ. ПЕРЕД ... 1.00   93.00     0.00
# 9 МЕСЯЦЕВ ФОЛИЕВАЯ К-ТА 0,4МГ. №30 ТАБ. П/П/О /... 1.00  144.00     0.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА    2.00  216.00     0.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.       2.00  208.00     0.00
# 911-ГЕЛЬ-БАЛЬЗАМ Д/ТЕЛА БИШОФИТ П/БОЛИ В СУСТАВ... 1.00  100.00     0.00
# ...                                                 ...     ...      ...
# Я САМАЯ ВАТНЫЕ ПАЛОЧКИ №100 СТАКАН                 1.00   65.00     0.00
# ЯНТАРНАЯ К-ТА 100МГ. №10 ТАБ. (БАД) /МАРБИОФАРМ/   2.00   27.00     0.00
# ЯНТАРНАЯ К-ТА ПРЕМИУМ 100МГ. №20 ТАБ. (БАД) /БА... 1.00   52.00     0.00
# ЯНТАРНАЯ К-ТА ФОРП 100МГ. №10 ТАБ.                 3.00   28.00     0.00
# ЯРИНА №21 ТАБ. П/П/О                               1.00 1292.00     0.00
#
# [1876 rows x 3 columns]

# %%
groupped_df=groupped_df.sort_values('rel_kol', ascending=False)

# %%
groupped_df
# Out:
#                                                    drug     kol        roz  \
# 0                                                 ПАКЕТ  126.00     248.00
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...  186.00    2528.00
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/  234.00    3080.00
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/  274.00    3108.00
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...  309.00    7323.00
# ...                                                 ...     ...        ...
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 4585.69 1360361.30
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 4585.74 1361279.30
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 4585.78 1363279.30
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 4585.82 1364603.30
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 4585.84 1365591.30
#
#       rel_kol  cumsum_kol
# 0        0.03        0.03
# ...

# %%
groupped_df['cumsum_kol'] = groupped_df['rel_kol'].cumsum()

# %%
groupped_df
# Out:
#                                                    drug     kol        roz  \
# 0                                                 ПАКЕТ  126.00     248.00
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...  186.00    2528.00
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/  234.00    3080.00
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/  274.00    3108.00
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...  309.00    7323.00
# ...                                                 ...     ...        ...
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 4585.69 1360361.30
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 4585.74 1361279.30
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 4585.78 1363279.30
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 4585.82 1364603.30
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 4585.84 1365591.30
#
#       rel_kol  cumsum_kol
# 0        0.03        0.03
# ...

# %%
groupped_df['abc_kol'] = np.where(groupped_df['cumsum_kol']<0.8,'A',np.where(groupped_df['cumsum_kol']<0.95,'B','C'))

# %%
groupped_df
# Out:
#                                                    drug     kol        roz  \
# 0                                                 ПАКЕТ  126.00     248.00
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...  186.00    2528.00
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/  234.00    3080.00
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/  274.00    3108.00
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...  309.00    7323.00
# ...                                                 ...     ...        ...
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 4585.69 1360361.30
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 4585.74 1361279.30
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 4585.78 1363279.30
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 4585.82 1364603.30
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 4585.84 1365591.30
#
#       rel_kol  cumsum_kol abc_kol
# ...

# %%
groupped_df['rel_roz'] = groupped_df['roz']/sum(groupped_df['roz'])
groupped_df=groupped_df.sort_values('rel_roz',ascending=False)
groupped_df['cumsum_roz']=groupped_df['rel_roz'].cumsum()
groupped_df['abc_roz']=np.where(groupped_df['cumsum_roz']<0.8,'A',np.where(groupped_df['cumsum_roz']<0.95,'B','C'))

# %%
groupped_df
# Out:
#                                                    drug     kol        roz  \
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 4585.84 1365591.30
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 4585.82 1364603.30
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 4585.78 1363279.30
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 4585.74 1361279.30
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 4585.69 1360361.30
# ...                                                 ...     ...        ...
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...  309.00    7323.00
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/  274.00    3108.00
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/  234.00    3080.00
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...  186.00    2528.00
# 0                                                 ПАКЕТ  126.00     248.00
#
#       rel_kol  cumsum_kol abc_kol  rel_roz  cumsum_roz abc_roz
# ...

# %%
groupped_df[['roz', 'kol', 'abc_kol', 'abc_roz']].reset_index().sort_values('roz',ascending=False)
# Out:
#       index        roz     kol abc_kol abc_roz
# 0      1875 1365591.30 4585.84       C       A
# 1      1874 1364603.30 4585.82       C       A
# 2      1873 1363279.30 4585.78       C       A
# 3      1872 1361279.30 4585.74       C       A
# 4      1871 1360361.30 4585.69       C       A
# ...     ...        ...     ...     ...     ...
# 1871      4    7323.00  309.00       A       C
# 1872      3    3108.00  274.00       A       C
# 1873      2    3080.00  234.00       A       C
# 1874      1    2528.00  186.00       A       C
# 1875      0     248.00  126.00       A       C
#
# [1876 rows x 5 columns]

# %%
df1= df[['drug','kol','roz']]

# %%
df1
# Out:
#                                                    drug  kol    roz
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 210.00
# 4                      ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/ 1.00 787.00
# ...                                                 ...  ...    ...
# 4457  КЕТОРОЛ ЭКСПРЕСС 10МГ. №20 ТАБ. ДИСПЕРГ. /Д-Р ... 1.00  75.00
# 4458                           АНТИПОЛИЦАЙ ВАЙТ №6 ТАБ. 1.00  93.00
# 4459  СИЛДЕНАФИЛ-СЗ 50МГ. №10 ТАБ. П/П/О /СЕВЕРНАЯ З... 1.00 396.00
# 4460                         ТОБРАЗОН 5МЛ. ГЛ.КАПЛИ ФЛ. 1.00 419.00
# 4461  БЕЛЬВЕДЕР ЛАК П/ОБГРЫЗАНИЯ НОГТЕЙ 8МЛ. [BELWEDER] 1.00 346.00
#
# [4462 rows x 3 columns]

# %%
index(['drug','kol','roz'],dtype='object')

# %%
a=list(df1.columns)
a.remove('kol')

# %%
a
# Out:
# ['drug', 'roz']

# %%
from operator import index
perfom_abc(df1, index='drug')

# %%
from ast import Index
def perfom_abc(df, index):
  ...

  ...
  cols=list(df.columns)
  cols.remove(index)
  groupped_df=df.groupby(index).agg({col:sum for col in cols})
  for col in cols:
      groupped_df[f'rel_{col}'] = groupped_df[col]/sum(groupped_df[col])
      groupped_df=groupped_df.sort_values(f'rel_{col}',ascending=False)
      groupped_df[f'cumsum_{col}']=groupped_df[f'rel_{col}'].cumsum()
      groupped_df[f'abc_{col}']=np.where(groupped_df[f'cumsum_{col}']<0.8,'A',np.where(groupped_df[f'cumsum_{col}']<0.95,'B','C'))
  groupped_df[cols + [f'abc_{col}' for col in cols]]

# %%
groupped_df
# Out:
#                                                    drug     kol        roz  \
# 1875  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/... 4585.84 1365591.30
# 1874   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM] 4585.82 1364603.30
# 1873  ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР... 4585.78 1363279.30
# 1872  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM] 4585.74 1361279.30
# 1871  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ.... 4585.69 1360361.30
# ...                                                 ...     ...        ...
# 4     СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...  309.00    7323.00
# 3           ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/  274.00    3108.00
# 2      НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/  234.00    3080.00
# 1     ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...  186.00    2528.00
# 0                                                 ПАКЕТ  126.00     248.00
#
#       rel_kol  cumsum_kol abc_kol  rel_roz  cumsum_roz abc_roz
# ...

# %%
perfom_abc(df1, index='drug')

# %%
perfom_abc
# Out:
# <function __main__.perfom_abc(df, index)>

# %% [markdown]
# Динамика продаж

# %%
upload=files.upload()
# Out:
#      <input type="file" id="files-18e83431-5511-426b-9f2d-bcc88ee783f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18e83431-5511-426b-9f2d-bcc88ee783f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv('data1.csv', encoding='1251')

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-11  10:15:35     2173  2004598       2   22577
# 1  2022-08-11  10:27:46     2174  2004598       2   22577
# 2  2022-08-11  10:27:46     2174  2004598       2   22577
# 3  2022-08-11  10:27:46     2174  2004598       2   22577
# 4  2022-08-11  10:33:56     2175  2004598       2   22577
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18      45399
# 1  Розничная реализация       15     261519
# 2  Розничная реализация       15     460864
# 3  Розничная реализация       15     172823
# 4  Розничная реализация       18      79056
#
#                                            DR_NDrugs        DR_Suppl  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...  Катрен г.Химки
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.  Катрен г.Химки
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...  Катрен г.Химки
# ...

# %%
df.DR_Dat.unique()
# Out:
# array(['2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04',
#        '2022-08-05'], dtype=object)

# %%
df=df.groupby('DR_Dat').apply(lambda x: sum(x['DR_Kol']*x['DR_CRoz']-x['DR_SDisc']))

# %%
df
# Out:
# DR_Dat
# 2022-08-01   84681.52
# 2022-08-02   71389.37
# 2022-08-03   78050.82
# 2022-08-04   59187.36
# 2022-08-05   56458.81
# dtype: float64

# %%
df.rolling(2).sum()
# Out:
# DR_Dat
# 2022-08-01         NaN
# 2022-08-02   156070.89
# 2022-08-03   149440.19
# 2022-08-04   137238.18
# 2022-08-05   115646.17
# dtype: float64

# %%
df.rolling(2).apply(lambda x: (x[1]- x[0])/x[0])
# Out:
# DR_Dat
# 2022-08-01     NaN
# 2022-08-02   -0.16
# 2022-08-03    0.09
# 2022-08-04   -0.24
# 2022-08-05   -0.05
# dtype: float64

# %%
df.shift(1)
# Out:
# DR_Dat
# 2022-08-01        NaN
# 2022-08-02   84681.52
# 2022-08-03   71389.37
# 2022-08-04   78050.82
# 2022-08-05   59187.36
# dtype: float64

# %%
df=df.pct_change(1)

# %%
df
# Out:
# DR_Dat
# 2022-08-01     NaN
# 2022-08-02   -0.16
# 2022-08-03    0.09
# 2022-08-04   -0.24
# 2022-08-05   -0.05
# dtype: float64

# %% [markdown]
# **XYZ- анализ**

# %%
df= pd.read_csv('data1.csv', encoding='1251')

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-01  08:06:18     1272  13002561      13   22589
# 1  2022-08-01  08:38:53     1273  13002561      13   22589
# 2  2022-08-01  08:55:38     1274  13002561      13   22589
# 3  2022-08-01  09:00:40     1275  13002561      13   22589
# 4  2022-08-01  09:04:05     1276  13002561      13   22589
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18     144734
# 1  Розничная реализация       15      69661
# 2  Розничная реализация       18     190635
# 3  Розничная реализация       18     276370
# 4  Розничная реализация       15       2303
#
#                                            DR_NDrugs  \
# 0                            ГАСТАЛ №12 ТАБ. Д/РАСС.
# 1   ТОБРОПТ 0,3% 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /РОМФАРМ/
# 2  ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-М...
# 3  АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/Ф...
# 4                   ЭНАМ 2,5МГ. №20 ТАБ. /Д-Р РЕДДИ/
#
# ...

# %%
df= df.groupby(['DR_Dat','DR_NDrugs']).agg({'DR_Kol':sum})

# %%
df
# Out:
#                                                                DR_Kol
# DR_Dat     DR_NDrugs
# 2022-08-01 911-ВЕНОЛГОН ГЕЛЬ Д/НОГ ПРИ ТЯЖЕСТИ,БОЛИ,ОТЕКАХ...    1.00
#            L-ТИРОКСИН 100МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/            1.00
#            L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/              1.00
#            L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/             2.00
#            NF ВАТА ХИРУРГ. СТЕР. 100Г. /НЬЮФАРМ/                 1.00
# ...                                                               ...
# 2022-08-05 ЭВО ПАНТЕНОЛ ПОМАДА ГИГИЕН. 2,8Г. [EVO] /АВАНТА/      1.00
#            ЭМОКСИПИН 10МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ. КРЫШ/КАП.     2.00
#            ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. Ф...    1.00
#            ЭТОРИАКС 90МГ. №7 ТАБ. П/П/О                          1.00
#            ЮНИДОКС СОЛЮТАБ 100МГ. №20 ТАБ.ДИСПЕРГ. /АСТЕЛЛАС/    1.00
#
# [1089 rows x 1 columns]

# %%
df.reset_index().groupby('DR_NDrugs').apply(lambda x: x.std()/x.mean())
# Out:
# <ipython-input-183-4c055be211fc>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.reset_index().groupby('DR_NDrugs').apply(lambda x: x.std()/x.mean())
# <ipython-input-183-4c055be211fc>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.reset_index().groupby('DR_NDrugs').apply(lambda x: x.std()/x.mean())
# ...

# %%
a={'b':[1,2]}
a=pd.DataFrame(a)

# %%
a
# Out:
#    b
# 0  1
# 1  2

# %%
a['b'].std()
# Out:
# 0.7071067811865476

# %%
np.std(a['b'])
# Out:
# 0.5

# %%
df1 = df.reset_index().groupby('DR_NDrugs').agg({'DR_Dat':'count'}).reset_index()

# %%
df1
# Out:
#                                              DR_NDrugs  DR_Dat
# 0    911-ВЕНОЛГОН ГЕЛЬ Д/НОГ ПРИ ТЯЖЕСТИ,БОЛИ,ОТЕКА...       1
# 1    911-ГЕЛЬ-БАЛЬЗАМ Д/НОГ КОНСКИЙ КАШТАН 100МЛ. ТУБА       1
# 2    911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ РАЗОГР. ОКОПНИК+МУ...       1
# 3           L-ТИРОКСИН 100МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/       1
# 4           L-ТИРОКСИН 150МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/       1
# ..                                                 ...     ...
# 798  ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. ...       4
# 799            ЭСПУМИЗАН 40МГ. №25 КАПС. /БЕРЛИН-ХЕМИ/       1
# 800                       ЭТОРИАКС 90МГ. №7 ТАБ. П/П/О       1
# 801  ЮНИДОКС СОЛЮТАБ 100МГ. №10 ТАБ.ДИСПЕРГ. /АСТЕЛ...       1
# 802  ЮНИДОКС СОЛЮТАБ 100МГ. №20 ТАБ.ДИСПЕРГ. /АСТЕЛ...       1
#
# [803 rows x 2 columns]

# %%
xyz_names = list(df1[df1['DR_Dat']>1]['DR_NDrugs'])

# %%
xyz_names
# Out:
# ['L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/',
#  'L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/',
#  'АЗАРГА 10МГ/МЛ.+5МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП.',
#  'АМОКСИЦИЛЛИН 500МГ. №16 КАПС. /ХЕМОФАРМ/',
#  'АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/ФАРМСТАНДАРТ/',
#  'АСЕПТИКА САЛФЕТКА СПИРТОВАЯ 60Х100 №20',
#  'АСКОРБИНКА ЛУНТИК ВИТ.С КЛУБНИКА №10 ТАБ. (30Г.) /ФАРМ-ПРО/ТИГОДА-ФАРМ/',
#  'АСКОРБИНКА ЛУНТИК ВИТ.С №10 ТАБ. (30Г.) /ФАРМ-ПРО/ТИГОДА-ФАРМ/',
#  'АСКОРБИНОВАЯ К-ТА 25МГ. ВИШНЯ №10 ТАБ. КРУТКА САХ. /АСКОПРОМ/',
#  'АСКОРБИНОВАЯ К-ТА 25МГ. ЯБЛОКО №10 ТАБ. КРУТКА САХ. /АСКОПРОМ/',
#  'АСПАРКАМ №60 ТАБ. /ФАРМАПОЛ-ВОЛГА/',
#  'АСПЕРА СУПЕРЧИСТОТЕЛ 3МЛ. ФЛ.',
#  'АТЕНОЛОЛ РЕНЕВАЛ 50МГ. №30 ТАБ. /ОБНОВЛЕНИЕ/',
#  'АТОПИК КРЕМ-СТИК УСПОКАИВАЮЩИЙ Д/ДЕТ. 0+ 4,9МЛ. ПЕНАЛ [ATOPIC]',
#  'АТОРВАСТАТИН-СЗ 20МГ. №60 ТАБ. П/П/О /СЕВЕРНАЯ ЗВЕЗДА/',
#  'АФОБАЗОЛ 10МГ. №60 ТАБ.',
#  'АЦЕТИЛСАЛИЦИЛОВАЯ К-ТА 500МГ. №20 ТАБ. /ФАРМСТАНДАРТ/',
# ...

# %%
df=df.reset_index()

# %%
df= df[df['DR_NDrugs'].isin(xyz_names)]

# %%
df = df.groupby('DR_NDrugs').apply(lambda x: x.std()/x.mean())
# Out:
# <ipython-input-209-e91969e379e2>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.groupby('DR_NDrugs').apply(lambda x: x.std()/x.mean())
# <ipython-input-209-e91969e379e2>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.groupby('DR_NDrugs').apply(lambda x: x.std()/x.mean())
# ...

# %%
df
# Out:
#                                                     index  DR_Kol
# DR_NDrugs
# L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/             1.41    0.00
# L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/            1.40    0.47
# АЗАРГА 10МГ/МЛ.+5МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП.    1.36    0.00
# АМОКСИЦИЛЛИН 500МГ. №16 КАПС. /ХЕМОФАРМ/             0.60    0.47
# АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/ФА...   1.13    0.43
# ...                                                   ...     ...
# ЭВО ПАНТЕНОЛ ПОМАДА ГИГИЕН. 2,8Г. [EVO] /АВАНТА/     0.15    0.47
# ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-МА...   0.42    0.00
# ЭМОКСИПИН 10МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ. КРЫШ/КАП.    0.31    0.47
# ЭНАЛАПРИЛ 5МГ. №20 ТАБ. /ХЕМОФАРМ/                   0.41    0.47
# ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. Ф...   0.55    0.29
#
# [182 rows x 2 columns]

# %%
df['xyz'] = np.where(df['DR_Kol']<0.1, 'x', np.where(df['DR_Kol']<0.25, 'y', 'z'))

# %%
df
# Out:
#                                                     index  DR_Kol xyz
# DR_NDrugs
# L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/             1.41    0.00   x
# L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/            1.40    0.47   z
# АЗАРГА 10МГ/МЛ.+5МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП.    1.36    0.00   x
# АМОКСИЦИЛЛИН 500МГ. №16 КАПС. /ХЕМОФАРМ/             0.60    0.47   z
# АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/ФА...   1.13    0.43   z
# ...                                                   ...     ...  ..
# ЭВО ПАНТЕНОЛ ПОМАДА ГИГИЕН. 2,8Г. [EVO] /АВАНТА/     0.15    0.47   z
# ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-МА...   0.42    0.00   x
# ЭМОКСИПИН 10МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ. КРЫШ/КАП.    0.31    0.47   z
# ЭНАЛАПРИЛ 5МГ. №20 ТАБ. /ХЕМОФАРМ/                   0.41    0.47   z
# ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. Ф...   0.55    0.29   z
#
# [182 rows x 3 columns]
